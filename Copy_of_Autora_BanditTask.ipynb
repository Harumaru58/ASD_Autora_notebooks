# %% [markdown]
# <a href="https://colab.research.google.com/github/Harumaru58/ASD_Autora_notebooks/blob/main/Copy_of_Autora_BanditTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # preliminaries
#
#
# *   Installations
# *   Imports

# %%
# !pip install -r /content/drive/MyDrive/Closed_loop_Project/req.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/drive/MyDrive/Closed_loop_Project/req.txt'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # TO do list:
#
#
# *   run-1 : when γ=0
# *   run-2 : when γ!=0 but is very small
# *   run-3 : when γ is not small
# *   run-4 : Define another theorist
# *   any other idea?

# %%
# *** IMPORTS *** #

# Python Core
from dataclasses import dataclass, field
from typing import List
import random, json

# External Vendors
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator
import torch

# General Aut oRA
from autora.variable import VariableCollection, Variable
from autora.state import StandardState, on_state, Delta
"""
Bandit Workflow
    Reward Trajectory as Conditions
    Theorist: Rnn Sindy Theorist
    Experimentalist: Random Sampling + Model Disagreement
    Runner: Synthetic + Firebase Runner + Prolific recruitment)
"""

# *** IMPORTS *** #

# Python Core
from dataclasses import dataclass, field
from typing import List
import random, json

# External Vendors
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator
import torch

# General AutoRA
from autora.variable import VariableCollection, Variable
from autora.state import StandardState, on_state, Delta

# Experimentalists
from autora.experimentalist.bandit_random import bandit_random_pool
from autora.experimentalist.model_disagreement import model_disagreement_sampler_custom_distance

# Experiment Runner
from autora.experiment_runner.synthetic.psychology.q_learning import q_learning
from autora.experiment_runner.firebase_prolific import firebase_runner, firebase_prolific_runner

# Theorist
from autora.theorist.rnn_sindy_rl import RNNSindy
from autora.theorist.rnn_sindy_rl.utils.parse import parse as parse_equation
RUNNER_TYPE = 'synthetic'

TRIALS_PER_PARTICIPANTS = 100
SAMPLES_PER_CYCLE = 1
PARTICIPANTS_PER_CYCLE = 40
CYCLES = 4
INITIAL_REWARD_PROBABILITY_RANGE = [.2, .8]
SIGMA_RANGE = [.2, .2]

EPOCHS = 10 # 100



seed = 11

# for reproducible results:
if seed is not None:
    np.random.seed(seed)
    torch.manual_seed(seed)

# *** AUTORA SETUP *** #

# ** Set up variables ** #
# independent variable is "reward-trajectory": A 2 x n_trials Vector with entries between 0 and 1
# dependent variable is "choice-trajectory": A 2 x n_trials Vector with boolean entries (one hot encoded)

variables = VariableCollection(
    independent_variables=[Variable(name="reward-trajectory")
    ,Variable(name='previous-choice-trajectory')
    ],
    dependent_variables=[Variable(name="choice-trajectory")]
)


@dataclass(frozen=True)
class RnnState(StandardState):
    models_additional:  List[BaseEstimator] = field(
        default_factory=list,
        metadata={"delta": "extend"},
    )

# initialize the state:
state = RnnState(variables=variables)

@on_state()
def pool_on_state(num_samples, n_trials=TRIALS_PER_PARTICIPANTS): ##This only defines the rewards, and not the choices##
    """
    This is creates `num_samples` randomized reward-trajectories of length `n_trials`
    """
    sigma = np.random.uniform(SIGMA_RANGE[0], SIGMA_RANGE[1])
    trajectory_array = bandit_random_pool(
        num_rewards=2,
        sequence_length=n_trials,
        initial_probabilities=[INITIAL_REWARD_PROBABILITY_RANGE, INITIAL_REWARD_PROBABILITY_RANGE],
        sigmas=[sigma, sigma],
        num_samples=num_samples
    )
    trajectory_df = pd.DataFrame({'reward-trajectory': trajectory_array})
    return Delta(conditions=trajectory_df)


def custom_distance(prob_array_a, prob_array_b):
    return np.mean([(prob_array_a[0] - prob_array_b[0])**2 + (prob_array_a[1] - prob_array_b[1])**2])

###############  Experimentalist ##########################

@on_state()
def model_disagreement_on_state(
        conditions, models, models_additional, num_samples):
    conditions = model_disagreement_sampler_custom_distance(
        conditions=conditions['reward-trajectory'],
        models=[models[-1], models_additional[-1]],
        distance_fct=custom_distance,
        num_samples=num_samples,
    )
    return Delta(conditions=conditions)
################# DATA ##########################
runner = q_learning()

@on_state()
def runner_on_state_synthetic(conditions):
    choices, choice_probabilities = runner.run(conditions, return_choice_probabilities=True)
    # print(choices)
    experiment_data = pd.DataFrame({
        'reward-trajectory': conditions['reward-trajectory'].tolist(),
        'choice-trajectory': choices,
        'previous-choice-trajectory': [np.concatenate((np.array([[0,0]]),choices[0][:-1]))],
        'choice-probability-trajectory': choice_probabilities
    })
    return Delta(experiment_data=experiment_data)

####################   Theorist   ####################

theorist = RNNSindy(2, epochs=EPOCHS, polynomial_degree=2)
theorist_additional = RNNSindy(2, epochs=EPOCHS, polynomial_degree=1)

@on_state()
def theorist_on_state(experiment_data):
    # x = [np.array(experiment_data[['reward-trajectory']]),np.array(experiment_data[['previous-choice-trajectory']])]#
    x = experiment_data['reward-trajectory']
    y = experiment_data['choice-trajectory']
    return Delta(models=[theorist.fit(x, y)])


@on_state()
def theorist_additional_on_state(experiment_data):
    x = experiment_data['reward-trajectory']
    y = experiment_data['choice-trajectory']
    return Delta(models_additional=[theorist_additional.fit(x, y)])


################ LOOP #########################


for c in range(1, CYCLES + 1):

    if len(state.models) > 0:
        state = pool_on_state(state, num_samples=20)
        state = model_disagreement_on_state(state, num_samples=SAMPLES_PER_CYCLE)
    else:
        state = pool_on_state(state, num_samples=SAMPLES_PER_CYCLE)

    if RUNNER_TYPE == 'synthetic':
        state = runner_on_state_synthetic(state)

    state = theorist_on_state(state)
    state = theorist_additional_on_state(state)

    model = state.models[-1]
    model_additional = state.models_additional[-1]

    equations_model = parse_equation(model)
    equation_model_additional = parse_equation(model_additional)

    print('# MODEL DEGREE = 2#')
    print(f'chosen: {equations_model[0]}')
    print(f'non chosen: {equations_model[1]}')

    print('# MODEL DEGREE = 1#')
    print(f'chosen: {equation_model_additional[0]}')
    print(f'non chosen: {equation_model_additional[1]}')
# Out:
# Training the RNN...
# Epoch 1/10 --- Loss: 0.4009800; Time: 1.8545s; Convergence value: 5.99e-01
# Epoch 2/10 --- Loss: 0.3263386; Time: 1.8920s; Convergence value: 3.28e-01
# Epoch 3/10 --- Loss: 0.2107560; Time: 2.5787s; Convergence value: 2.52e-01
# Epoch 4/10 --- Loss: 0.4887829; Time: 2.3429s; Convergence value: 2.59e-01
# Epoch 5/10 --- Loss: 0.8647758; Time: 1.7620s; Convergence value: 2.85e-01
# Epoch 6/10 --- Loss: 0.7108431; Time: 1.7563s; Convergence value: 2.59e-01
# Epoch 7/10 --- Loss: 0.5997140; Time: 1.7523s; Convergence value: 2.33e-01
# Epoch 8/10 --- Loss: 0.6234410; Time: 1.8064s; Convergence value: 1.98e-01
# Epoch 9/10 --- Loss: 0.7282191; Time: 1.9464s; Convergence value: 1.83e-01
# Epoch 10/10 --- Loss: 0.5854306; Time: 2.4986s; Convergence value: 1.48e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.6688033; Time: 0.1974s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 20.41 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.0831e-02 ... 5.0140e-02 ...          3 ... 6.0971e-02
# (xQf)[k+1] = 0.084 1 + 0.897 xQf[k] + 0.021 xQf[k]^2
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.2493e-02 ... 3.8478e-02 ...          6 ... 5.0971e-02
# (xQr)[k+1] = -0.046 1 + 0.879 xQr[k] + 0.082 cr[k] + -0.012 xQr[k]^2 + 0.045 xQr[k] cr[k] + 0.082 cr[k]^2
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 7.7191e-03 ... 4.1119e-02 ...          5 ... 4.8838e-02
#          1 ... 7.6765e-03 ... 4.1157e-02 ...          5 ... 4.8834e-02
# (xQc)[k+1] = 0.185 1 + 0.778 xQc[k] + 0.253 cQr[k] + 0.012 xQc[k]^2 + -0.019 xQc[k] cQr[k]
# Beta for SINDy: 0.6210001707077026
# Training the RNN...
# Epoch 1/10 --- Loss: 1.0521649; Time: 2.2217s; Convergence value: 5.22e-02
# Epoch 2/10 --- Loss: 1.6834143; Time: 1.7926s; Convergence value: 3.51e-01
# Epoch 3/10 --- Loss: 0.8340217; Time: 1.7539s; Convergence value: 5.29e-01
# Epoch 4/10 --- Loss: 1.0939350; Time: 1.7687s; Convergence value: 4.55e-01
# Epoch 5/10 --- Loss: 1.5583626; Time: 1.7430s; Convergence value: 4.58e-01
# Epoch 6/10 --- Loss: 0.8652532; Time: 1.7414s; Convergence value: 5.05e-01
# Epoch 7/10 --- Loss: 1.0301185; Time: 2.4230s; Convergence value: 4.46e-01
# Epoch 8/10 --- Loss: 1.2275751; Time: 2.6461s; Convergence value: 4.06e-01
# Epoch 9/10 --- Loss: 0.5663074; Time: 1.8111s; Convergence value: 4.43e-01
# Epoch 10/10 --- Loss: 0.7422952; Time: 1.8496s; Convergence value: 4.29e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.6895328; Time: 0.1732s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 19.93 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 7.7544e-04 ... 3.8774e-02 ...          2 ... 3.9550e-02
# (xQf)[k+1] = 0.316 1 + 0.546 xQf[k]
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 3.3913e-03 ... 8.5367e-02 ...          3 ... 8.8758e-02
# (xQr)[k+1] = 0.209 1 + 0.891 xQr[k] + -0.261 cr[k]
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 2.8838e-03 ... 3.5715e-02 ...          3 ... 3.8599e-02
# (xQc)[k+1] = 0.094 1 + 0.623 xQc[k] + 0.149 cQr[k]
# Beta for SINDy: 0.33130019903182983
#
# Disovered model:
#
# Disovered model:
# # MODEL DEGREE = 2#
# chosen: Q_{chosen,}_{t+1}=0.045*Reward*Q_{chosen,}_{t} + 0.164*Reward + 0.879*Q_{chosen,}_{t} - 0.046
# non chosen: Q_{not chosen,}_{t+1}=0.251*\frac{dQ_{chosen}}{dt} + 0.7*Q_{not chosen,}_{t} + 0.25
# # MODEL DEGREE = 1#
# chosen: Q_{chosen,}_{t+1}=-0.261*Reward + 0.891*Q_{chosen,}_{t} + 0.209
# non chosen: Q_{not chosen,}_{t+1}=0.149*\frac{dQ_{chosen}}{dt} + 0.34*Q_{not chosen,}_{t} + 0.291
# Training the RNN...
# Epoch 1/10 --- Loss: 0.7274945; Time: 1.7160s; Convergence value: 2.73e-01
# Epoch 2/10 --- Loss: 0.5877239; Time: 1.8274s; Convergence value: 2.04e-01
# Epoch 3/10 --- Loss: 0.8288759; Time: 1.7871s; Convergence value: 2.17e-01
# Epoch 4/10 --- Loss: 0.7379033; Time: 1.7669s; Convergence value: 1.82e-01
# Epoch 5/10 --- Loss: 0.6631694; Time: 1.7975s; Convergence value: 1.57e-01
# Epoch 6/10 --- Loss: 0.6975501; Time: 2.0850s; Convergence value: 1.33e-01
# Epoch 7/10 --- Loss: 0.6615317; Time: 2.6493s; Convergence value: 1.15e-01
# Epoch 8/10 --- Loss: 0.5608650; Time: 2.0408s; Convergence value: 1.12e-01
# Epoch 9/10 --- Loss: 0.5774159; Time: 1.7644s; Convergence value: 9.70e-02
# Epoch 10/10 --- Loss: 0.8611242; Time: 1.7626s; Convergence value: 1.12e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.8232241; Time: 0.1395s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 19.34 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.0610e-02 ... 5.1890e-02 ...          3 ... 6.2500e-02
# (xQf)[k+1] = 0.100 1 + 0.917 xQf[k] + 0.030 xQf[k]^2
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.2867e-02 ... 3.8510e-02 ...          6 ... 5.1377e-02
# (xQr)[k+1] = -0.014 1 + 0.904 xQr[k] + 0.066 cr[k] + -0.031 xQr[k]^2 + 0.022 xQr[k] cr[k] + 0.066 cr[k]^2
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 6.3140e-03 ... 3.6552e-02 ...          5 ... 4.2866e-02
#          1 ... 6.3026e-03 ... 3.6563e-02 ...          5 ... 4.2866e-02
# (xQc)[k+1] = 0.103 1 + 0.782 xQc[k] + 0.266 cQr[k] + 0.032 xQc[k]^2 + -0.057 xQc[k] cQr[k]
# Beta for SINDy: 1.4356205463409424
# Training the RNN...
# Epoch 1/10 --- Loss: 0.6749505; Time: 1.7078s; Convergence value: 3.25e-01
# Epoch 2/10 --- Loss: 0.9587497; Time: 1.9566s; Convergence value: 3.04e-01
# Epoch 3/10 --- Loss: 0.6056184; Time: 2.0768s; Convergence value: 3.21e-01
# Epoch 4/10 --- Loss: 0.6078221; Time: 2.6521s; Convergence value: 2.33e-01
# Epoch 5/10 --- Loss: 0.6951554; Time: 2.0614s; Convergence value: 1.99e-01
# Epoch 6/10 --- Loss: 0.6106786; Time: 1.7755s; Convergence value: 1.76e-01
# Epoch 7/10 --- Loss: 0.5802504; Time: 1.7636s; Convergence value: 1.50e-01
# Epoch 8/10 --- Loss: 0.7576376; Time: 1.8339s; Convergence value: 1.53e-01
# Epoch 9/10 --- Loss: 0.7293258; Time: 1.8206s; Convergence value: 1.33e-01
# Epoch 10/10 --- Loss: 0.6034352; Time: 1.8774s; Convergence value: 1.18e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.6469750; Time: 0.2238s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 19.76 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 2.0002e-04 ... 5.9295e-02 ...          2 ... 5.9495e-02
# (xQf)[k+1] = 0.606 1 + 0.478 xQf[k]
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 2.7784e-03 ... 8.3183e-02 ...          3 ... 8.5962e-02
# (xQr)[k+1] = 0.228 1 + 0.859 xQr[k] + -0.297 cr[k]
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 3.7319e-03 ... 2.8114e-02 ...          3 ... 3.1845e-02
# (xQc)[k+1] = -0.017 1 + 0.586 xQc[k] + 0.150 cQr[k]
# Beta for SINDy: 0.17617937922477722
#
# Disovered model:
#
# Disovered model:
# # MODEL DEGREE = 2#
# chosen: Q_{chosen,}_{t+1}=0.132*Reward - 0.031*Q_{chosen,}_{t}**2 + 0.904*Q_{chosen,}_{t}
# non chosen: Q_{not chosen,}_{t+1}=-0.052*\frac{dQ_{chosen}}{dt}*Q_{not chosen,}_{t} + 0.26*\frac{dQ_{chosen}}{dt} + 0.051*Q_{not chosen,}_{t}**2 + 0.723*Q_{not chosen,}_{t} + 0.182
# # MODEL DEGREE = 1#
# chosen: Q_{chosen,}_{t+1}=-0.297*Reward + 0.859*Q_{chosen,}_{t} + 0.228
# non chosen: Q_{not chosen,}_{t+1}=0.15*\frac{dQ_{chosen}}{dt} + 0.28*Q_{not chosen,}_{t} + 0.338
# Training the RNN...
# Epoch 1/10 --- Loss: 0.9200222; Time: 1.9622s; Convergence value: 8.00e-02
# Epoch 2/10 --- Loss: 1.1837502; Time: 1.8203s; Convergence value: 1.75e-01
# Epoch 3/10 --- Loss: 0.8574628; Time: 2.5694s; Convergence value: 2.29e-01
# Epoch 4/10 --- Loss: 0.9326715; Time: 2.6705s; Convergence value: 1.87e-01
# Epoch 5/10 --- Loss: 1.0249074; Time: 1.9694s; Convergence value: 1.65e-01
# Epoch 6/10 --- Loss: 0.9452093; Time: 1.9358s; Convergence value: 1.48e-01
# Epoch 7/10 --- Loss: 0.7835914; Time: 1.8394s; Convergence value: 1.50e-01
# Epoch 8/10 --- Loss: 0.8949146; Time: 1.9341s; Convergence value: 1.44e-01
# Epoch 9/10 --- Loss: 0.9808056; Time: 1.9290s; Convergence value: 1.35e-01
# Epoch 10/10 --- Loss: 1.0635017; Time: 2.7099s; Convergence value: 1.30e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.6181489; Time: 0.2278s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 21.57 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.0240e-02 ... 6.7724e-02 ...          3 ... 7.7964e-02
# (xQf)[k+1] = 0.032 1 + 0.963 xQf[k] + 0.041 xQf[k]^2
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.1605e-02 ... 5.2131e-02 ...          6 ... 6.3736e-02
# (xQr)[k+1] = 0.003 1 + 0.894 xQr[k] + 0.065 cr[k] + -0.029 xQr[k]^2 + 0.013 xQr[k] cr[k] + 0.065 cr[k]^2
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 8.5792e-03 ... 5.0883e-02 ...          5 ... 5.9462e-02
#          1 ... 8.5787e-03 ... 5.0883e-02 ...          5 ... 5.9462e-02
# (xQc)[k+1] = 0.064 1 + 0.841 xQc[k] + 0.232 cQr[k] + 0.032 xQc[k]^2 + -0.063 xQc[k] cQr[k]
# Beta for SINDy: 2.024477243423462
# Training the RNN...
# Epoch 1/10 --- Loss: 0.6850601; Time: 2.0881s; Convergence value: 3.15e-01
# Epoch 2/10 --- Loss: 0.5707661; Time: 1.8990s; Convergence value: 2.11e-01
# Epoch 3/10 --- Loss: 0.7476268; Time: 1.9198s; Convergence value: 1.99e-01
# Epoch 4/10 --- Loss: 0.7726160; Time: 1.8754s; Convergence value: 1.51e-01
# Epoch 5/10 --- Loss: 0.6703848; Time: 1.8116s; Convergence value: 1.39e-01
# Epoch 6/10 --- Loss: 1.0126477; Time: 2.2914s; Convergence value: 1.79e-01
# Epoch 7/10 --- Loss: 0.7813783; Time: 2.7456s; Convergence value: 1.88e-01
# Epoch 8/10 --- Loss: 0.8210614; Time: 2.0316s; Convergence value: 1.64e-01
# Epoch 9/10 --- Loss: 0.9233992; Time: 1.8402s; Convergence value: 1.55e-01
# Epoch 10/10 --- Loss: 0.8596675; Time: 1.8350s; Convergence value: 1.31e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.6810646; Time: 0.1519s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 20.49 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.4162e-01 ... 2.4545e-02 ...          1 ... 1.6616e-01
#          1 ... 2.0529e-02 ... 3.0548e-02 ...          1 ... 5.1077e-02
# (xQf)[k+1] = 0.554 xQf[k]
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 2.7611e-02 ... 7.3451e-02 ...          2 ... 1.0106e-01
#          1 ... 1.3041e-02 ... 7.3110e-02 ...          2 ... 8.6151e-02
# (xQr)[k+1] = 0.191 1 + 0.844 xQr[k]
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 2.1211e-03 ... 3.3941e-02 ...          3 ... 3.6062e-02
# (xQc)[k+1] = 0.106 1 + 0.555 xQc[k] + 0.260 cQr[k]
# Beta for SINDy: 0.4443848133087158
#
# Disovered model:
#
# Disovered model:
# # MODEL DEGREE = 2#
# chosen: Q_{chosen,}_{t+1}=0.13*Reward + 0.894*Q_{chosen,}_{t}
# non chosen: Q_{not chosen,}_{t+1}=-0.061*\frac{dQ_{chosen}}{dt}*Q_{not chosen,}_{t} + 0.23*\frac{dQ_{chosen}}{dt} + 0.064*Q_{not chosen,}_{t}**2 + 0.812*Q_{not chosen,}_{t} + 0.091
# # MODEL DEGREE = 1#
# chosen: Q_{chosen,}_{t+1}=0.844*Q_{chosen,}_{t} + 0.191
# non chosen: Q_{not chosen,}_{t+1}=0.26*\frac{dQ_{chosen}}{dt} + 0.307*Q_{not chosen,}_{t} + 0.106
# Training the RNN...
# Epoch 1/10 --- Loss: 0.9905507; Time: 1.8078s; Convergence value: 9.45e-03
# Epoch 2/10 --- Loss: 1.0068027; Time: 1.8335s; Convergence value: 1.30e-02
# Epoch 3/10 --- Loss: 0.9992557; Time: 1.8180s; Convergence value: 1.10e-02
# Epoch 4/10 --- Loss: 0.6450207; Time: 1.8739s; Convergence value: 1.06e-01
# Epoch 5/10 --- Loss: 1.0002828; Time: 2.0432s; Convergence value: 1.63e-01
# Epoch 6/10 --- Loss: 0.8780975; Time: 2.7212s; Convergence value: 1.56e-01
# Epoch 7/10 --- Loss: 0.7814352; Time: 2.2569s; Convergence value: 1.46e-01
# Epoch 8/10 --- Loss: 0.9240610; Time: 1.8333s; Convergence value: 1.46e-01
# Epoch 9/10 --- Loss: 0.7679477; Time: 1.8508s; Convergence value: 1.48e-01
# Epoch 10/10 --- Loss: 1.1507832; Time: 1.8715s; Convergence value: 1.93e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.3350429; Time: 0.1388s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 20.05 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 7.9137e-03 ... 7.1967e-02 ...          3 ... 7.9880e-02
# (xQf)[k+1] = 0.008 1 + 0.947 xQf[k] + 0.043 xQf[k]^2
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.0149e-02 ... 5.6682e-02 ...          6 ... 6.6831e-02
# (xQr)[k+1] = -0.010 1 + 0.875 xQr[k] + 0.087 cr[k] + -0.034 xQr[k]^2 + 0.010 xQr[k] cr[k] + 0.087 cr[k]^2
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 7.6081e-03 ... 6.2125e-02 ...          5 ... 6.9733e-02
#          1 ... 7.5817e-03 ... 6.2150e-02 ...          5 ... 6.9731e-02
# (xQc)[k+1] = 0.072 1 + 0.887 xQc[k] + 0.121 cQr[k] + 0.022 xQc[k]^2 + -0.030 xQc[k] cQr[k]
# Beta for SINDy: 2.089613199234009
# Training the RNN...
# Epoch 1/10 --- Loss: 0.9775730; Time: 1.8347s; Convergence value: 2.24e-02
# Epoch 2/10 --- Loss: 0.7599070; Time: 2.4619s; Convergence value: 1.23e-01
# Epoch 3/10 --- Loss: 0.7602703; Time: 2.9356s; Convergence value: 7.97e-02
# Epoch 4/10 --- Loss: 0.9970741; Time: 1.9114s; Convergence value: 1.23e-01
# Epoch 5/10 --- Loss: 1.1525921; Time: 1.8481s; Convergence value: 1.31e-01
# Epoch 6/10 --- Loss: 0.9547787; Time: 1.8476s; Convergence value: 1.44e-01
# Epoch 7/10 --- Loss: 1.0023091; Time: 1.8444s; Convergence value: 1.28e-01
# Epoch 8/10 --- Loss: 0.7901478; Time: 1.8438s; Convergence value: 1.41e-01
# Epoch 9/10 --- Loss: 0.8783703; Time: 2.4111s; Convergence value: 1.34e-01
# Epoch 10/10 --- Loss: 0.7930620; Time: 2.7397s; Convergence value: 1.34e-01
# Maximum number of training epochs reached.
# Model did not converge yet.
# Test the trained RNN on a test dataset...
# Epoch 1/1 --- Loss: 0.3374754; Time: 0.1481s; Convergence value: nan
# Maximum number of training epochs reached.
# Model did not converge yet.
# RNN training took 21.83 seconds.
#
# SINDy model for xQf:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.5680e-01 ... 3.0492e-02 ...          1 ... 1.8729e-01
#          1 ... 3.9970e-02 ... 3.7685e-02 ...          1 ... 7.7655e-02
# (xQf)[k+1] = 0.616 xQf[k]
#
# SINDy model for xQr:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.2014e-03 ... 6.5031e-02 ...          3 ... 6.6232e-02
# (xQr)[k+1] = 0.081 1 + 0.795 xQr[k] + 0.161 cr[k]
#
# SINDy model for xQc:
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.0519e-03 ... 3.0226e-02 ...          3 ... 3.1278e-02
# (xQc)[k+1] = 0.044 1 + 0.538 xQc[k] + 0.178 cQr[k]
# Beta for SINDy: 0.7914619445800781
#
# Disovered model:
#
# Disovered model:
# # MODEL DEGREE = 2#
# chosen: Q_{chosen,}_{t+1}=0.174*Reward - 0.034*Q_{chosen,}_{t}**2 + 0.875*Q_{chosen,}_{t}
# non chosen: Q_{not chosen,}_{t+1}=0.121*\frac{dQ_{chosen}}{dt} + 0.058*Q_{not chosen,}_{t}**2 + 0.84*Q_{not chosen,}_{t} + 0.079
# # MODEL DEGREE = 1#
# chosen: Q_{chosen,}_{t+1}=0.161*Reward + 0.795*Q_{chosen,}_{t} + 0.081
# non chosen: Q_{not chosen,}_{t+1}=0.178*\frac{dQ_{chosen}}{dt} + 0.331*Q_{not chosen,}_{t} + 0.044
